# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
from IPython.core.display import HTML
# Out:
# /tmp/ipykernel_15819/3286904718.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Método 1
#
# Dataset padrão:
#
# * Teste: 20% (aleatório)
# * Treino: 80% (aleatório)

# %%
for i in range(1, 6):
    display(HTML(f'<h1>Run 0{i}</h1>'))
    # df
    df = pd.read_json(path_or_buf=f'01/run_0{i}/training_log.jsonl', lines=True)

    df = pd.concat([df, pd.json_normalize(df["losses"]).add_prefix("losses.")], axis=1)
    df = pd.concat([df, pd.json_normalize(df["scores"]).add_prefix("scores.")], axis=1)
    df.drop(columns=["losses", "scores"], inplace=True)

    display(df)

    # plot
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    df.plot(x="epoch", y=["scores.ents_f", "scores.ents_p", "scores.ents_r"], ax=axes[0])
    axes[0].legend(["F1 Score", "Precision", "Recall"])

    df.plot(x="step", y=["scores.ents_f", "scores.ents_p", "scores.ents_r"], ax=axes[1])
    axes[1].legend(["F1 Score", "Precision", "Recall"])

    plt.suptitle("Performance evolution over training steps and epochs")

    plt.show()

    # df
    df_ents: pd.DataFrame

    with open(f'01/run_0{i}/out/model-best/meta.json') as json_file:
        data = json.load(json_file)
        df_ents = pd.DataFrame(data['performance']['ents_per_type']).T
        df_ents.columns = ["Precision", "Recall", "F1"]

    display(df_ents)

    # plot
    plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
    df_ents.plot(kind='bar')
    plt.title("Performance per entity type")
    plt.xlabel("Entity type")
    plt.ylabel("Performance")
    plt.show()
# Out:
# <h1>Run 01</h1>
#     epoch  step     score  losses.tok2vec   losses.ner  scores.ents_f  \
# 0       0     0  0.014742        0.000000   110.133315       1.474201
# 1       7   200  0.560510      441.875516  2079.188490      56.050955
# 2      16   400  0.721311      539.339127  1031.609301      72.131148
# 3      25   600  0.681818     1394.937170   917.007831      68.181818
# 4      34   800  0.620843       63.718975   190.245297      62.084257
# 5      45  1000  0.684807       44.388441    82.259123      68.480726
# 6      58  1200  0.701987      121.087823    74.673697      70.198675
# 7      75  1400  0.672986      147.674395    86.497293      67.298578
# 8      96  1600  0.645570     2667.121737   219.167118      64.556962
# 9     123  1800  0.651584      664.749971   131.105353      65.158371
# 10    157  2000  0.682028        0.033865     0.069355      68.202765
#
#     scores.ents_p  scores.ents_r
# 0        1.010101       2.727273
# 1       52.589641      60.000000
# 2       74.396135      70.000000
# 3       76.704545      61.363636
# 4       60.606061      63.636364
# 5       68.325792      68.636364
# 6       68.240343      72.272727
# 7       70.297030      64.545455
# 8       60.236220      69.545455
# 9       64.864865      65.454545
# 10      69.158879      67.272727
#                        Precision    Recall        F1
# TYPE_OF_APPEAL          0.837607  0.907407  0.871111
# GRANTED_TO_REVOKE       0.166667  0.105263  0.129032
# NOT_HEARD               0.681159  0.746032  0.712121
# NOT_GRANTED             1.000000  0.384615  0.555556
# GRANTED                 0.333333  0.111111  0.166667
# SUSPENDED               1.000000  0.250000  0.400000
# GRANTED_AND_INDICATED   0.000000  0.000000  0.000000
# RENDERED_MOOT           0.000000  0.000000  0.000000
# <h1>Run 02</h1>
#     epoch  step     score  losses.tok2vec   losses.ner  scores.ents_f  \
# 0       0     0  0.006257        0.000000    49.307688       0.625652
# 1       7   200  0.430823      374.067585  2180.779278      43.082312
# 2      15   400  0.662162       40.576685   435.183787      66.216216
# 3      23   600  0.686695      292.912740   442.037139      68.669528
# 4      32   800  0.707838       96.919906   162.876958      70.783848
# 5      41  1000  0.727273       45.628500    73.355159      72.727273
# 6      52  1200  0.697368       18.709230    38.463161      69.736842
# 7      65  1400  0.730512       84.991892    48.061554      73.051225
# 8      80  1600  0.712644      324.700854   103.950210      71.264368
# 9     100  1800  0.591006      356.505118   162.728787      59.100642
# 10    125  2000  0.666667     1084.903023   437.144488      66.666667
# 11    156  2200  0.714286      220.766751    81.851202      71.428571
# 12    195  2400  0.666667     1372.794952   126.501596      66.666667
# 13    243  2600  0.713959     1074.491693   158.395652      71.395881
# 14    293  2800  0.707692    38617.679412  1041.406976      70.769231
# 15    343  3000  0.701525     2646.097654   145.393442      70.152505
#
#     scores.ents_p  scores.ents_r
# 0        0.352319       2.790698
# 1       34.550562      57.209302
# 2       64.192140      68.372093
# 3       63.745020      74.418605
# 4       72.330097      69.302326
# 5       71.111111      74.418605
# 6       65.975104      73.953488
# 7       70.085470      76.279070
# 8       70.454545      72.093023
# 9       54.761905      64.186047
# 10      61.328125      73.023256
# 11      70.776256      72.093023
# 12      63.070539      70.697674
# 13      70.270270      72.558140
# 14      67.083333      74.883721
# 15      65.983607      74.883721
#                        Precision    Recall        F1
# TYPE_OF_APPEAL          0.779412  0.990654  0.872428
# GRANTED                 0.142857  0.250000  0.181818
# NOT_HEARD               0.807692  0.688525  0.743363
# GRANTED_TO_REVOKE       0.210526  0.235294  0.222222
# GRANTED_AND_INDICATED   0.000000  0.000000  0.000000
# NOT_GRANTED             0.769231  0.769231  0.769231
# RENDERED_MOOT           0.000000  0.000000  0.000000
# NOT_ENTERTAINED         0.000000  0.000000  0.000000
# SUSPENDED               0.000000  0.000000  0.000000
# <h1>Run 03</h1>
#     epoch  step     score  losses.tok2vec   losses.ner  scores.ents_f  \
# 0       0     0  0.056919        0.000000    41.933328       5.691855
# 1       7   200  0.584270      534.982617  3634.640488      58.426966
# 2      15   400  0.639175      121.716011   438.476758      63.917526
# 3      24   600  0.644351      686.109272   730.294967      64.435146
# 4      35   800  0.612975      236.642807   430.563181      61.297539
# 5      48  1000  0.674877      283.795264   391.632058      67.487685
# 6      64  1200  0.672897      853.205205   286.617368      67.289720
# 7      85  1400  0.721030      144.880971   122.227724      72.103004
# 8     110  1600  0.666667      885.130276   200.138473      66.666667
# 9     143  1800  0.712329     1130.061930   267.562841      71.232877
# 10    183  2000  0.670996     1028.842833   258.763249      67.099567
# 11    232  2200  0.706935     2976.903564   344.224786      70.693512
# 12    294  2400  0.654167      963.780090   309.031146      65.416667
# 13    361  2600  0.668076      861.032241   313.643095      66.807611
# 14    427  2800  0.693617      333.153265   288.711731      69.361702
# 15    494  3000  0.690678     1501.480740   353.170979      69.067797
#
#     scores.ents_p  scores.ents_r
# 0        3.634085      13.122172
# 1       58.035714      58.823529
# 2       58.712121      70.135747
# 3       59.922179      69.683258
# 4       60.619469      61.990950
# 5       74.054054      61.990950
# 6       69.565217      65.158371
# 7       68.571429      76.018100
# 8       61.776062      72.398190
# 9       71.889401      70.588235
# 10      64.315353      70.135747
# 11      69.911504      71.493213
# 12      60.617761      71.040724
# 13      62.698413      71.493213
# 14      65.461847      73.755656
# 15      64.940239      73.755656
#                        Precision    Recall        F1
# TYPE_OF_APPEAL          0.852459  0.962963  0.904348
# NOT_HEARD               0.630137  0.741935  0.681481
# GRANTED                 0.071429  0.125000  0.090909
# GRANTED_TO_REVOKE       0.294118  0.227273  0.256410
# NOT_GRANTED             0.785714  0.846154  0.814815
# RENDERED_MOOT           0.000000  0.000000  0.000000
# SUSPENDED               1.000000  0.250000  0.400000
# GRANTED_AND_INDICATED   0.000000  0.000000  0.000000
# NOT_ENTERTAINED         0.000000  0.000000  0.000000
# <h1>Run 04</h1>
#     epoch  step     score  losses.tok2vec   losses.ner  scores.ents_f  \
# 0       0     0  0.000672        0.000000    15.166665       0.067170
# 1       7   200  0.525386      450.637613  2058.301487      52.538631
# 2      16   400  0.666667       77.339932   588.118914      66.666667
# 3      26   600  0.664987       47.922859   243.261685      66.498741
# 4      39   800  0.694581       18.734406    38.354268      69.458128
# 5      54  1000  0.688525      256.280229   127.367250      68.852459
# 6      74  1200  0.652079       57.372084    57.628881      65.207877
# 7      99  1400  0.661247      402.205377   116.915404      66.124661
# 8     129  1600  0.643172      551.946559   137.025916      64.317181
# 9     167  1800  0.654028     3285.573963   205.520853      65.402844
# 10    213  2000  0.402036    37168.330423   865.415620      40.203562
# 11    271  2200  0.627803    34041.418783  2966.365819      62.780269
# 12    337  2400  0.644211     1598.358724   180.824785      64.421053
#
#     scores.ents_p  scores.ents_r
# 0        0.034868       0.913242
# 1       50.854701      54.337900
# 2       62.650602      71.232877
# 3       74.157303      60.273973
# 4       75.401070      64.383562
# 5       70.673077      67.123288
# 6       62.605042      68.036530
# 7       81.333333      55.707763
# 8       62.127660      66.666667
# 9       67.980296      63.013699
# 10      45.402299      36.073059
# 11      61.674009      63.926941
# 12      59.765625      69.863014
#                        Precision    Recall        F1
# TYPE_OF_APPEAL          0.897196  0.888889  0.893023
# SUSPENDED               0.666667  1.000000  0.800000
# NOT_GRANTED             0.769231  0.769231  0.769231
# NOT_HEARD               0.704545  0.492063  0.579439
# RENDERED_MOOT           0.090909  1.000000  0.166667
# GRANTED                 0.111111  0.125000  0.117647
# GRANTED_TO_REVOKE       0.000000  0.000000  0.000000
# GRANTED_AND_INDICATED   0.000000  0.000000  0.000000
# NOT_ENTERTAINED         0.000000  0.000000  0.000000
# <h1>Run 05</h1>
#     epoch  step     score  losses.tok2vec   losses.ner  scores.ents_f  \
# 0       0     0  0.018643        0.000000    25.846151       1.864259
# 1       7   200  0.612975      355.873741  2723.856985      61.297539
# 2      16   400  0.647887      154.768191   648.666635      64.788732
# 3      26   600  0.637209      108.858005   279.239972      63.720930
# 4      38   800  0.665138       41.636857    70.542938      66.513761
# 5      51  1000  0.663736      101.337125    97.257474      66.373626
# 6      66  1200  0.710462     1585.873109   251.225065      71.046229
# 7      85  1400  0.597403     2429.914936   268.250983      59.740260
# 8     109  1600  0.606557      569.712468   118.434280      60.655738
# 9     137  1800  0.623967     1150.120606   105.754793      62.396694
# 10    174  2000  0.630137    10464.387169   157.947761      63.013699
# 11    220  2200  0.678414    17857.538385   476.561979      67.841410
# 12    276  2400  0.639810     2617.423934   182.508268      63.981043
# 13    343  2600  0.657837    33003.143009   636.810543      65.783664
# 14    410  2800  0.638950     6354.314331   226.038126      63.894967
#
#     scores.ents_p  scores.ents_r
# 0        0.996264      14.479638
# 1       60.619469      61.990950
# 2       67.317073      62.443439
# 3       65.550239      61.990950
# 4       67.441860      65.610860
# 5       64.529915      68.325792
# 6       76.842105      66.063348
# 7       57.261411      62.443439
# 8       55.430712      66.968326
# 9       57.414449      68.325792
# 10      63.594470      62.443439
# 11      66.094421      69.683258
# 12      67.164179      61.085973
# 13      64.224138      67.420814
# 14      61.864407      66.063348
#                        Precision    Recall        F1
# TYPE_OF_APPEAL          0.816667  0.907407  0.859649
# NOT_HEARD               0.763636  0.688525  0.724138
# SUSPENDED               1.000000  0.250000  0.400000
# GRANTED_TO_REVOKE       0.000000  0.000000  0.000000
# NOT_GRANTED             0.555556  0.357143  0.434783
# GRANTED                 0.000000  0.000000  0.000000
# RENDERED_MOOT           0.000000  0.000000  0.000000
# NOT_ENTERTAINED         0.000000  0.000000  0.000000
# GRANTED_AND_INDICATED   0.000000  0.000000  0.000000

# %% [markdown]
# # Método 2
#
# * Teste: Dataset padrão (grande, inteiro)
# * Treino: Dataset especial (pequeno com 2/3 ementas de cada)

# %%
df = pd.read_json(path_or_buf='02/training_log.jsonl', lines=True)

df = pd.concat([df, pd.json_normalize(df["losses"]).add_prefix("losses.")], axis=1)
df = pd.concat([df, pd.json_normalize(df["scores"]).add_prefix("scores.")], axis=1)
df.drop(columns=["losses", "scores"], inplace=True)

df
# Out:
#     epoch  step     score  losses.tok2vec   losses.ner  scores.ents_f  \
# 0       0     0  0.029250        0.000000    67.526315       2.925046
# 1       1   200  0.486188      554.970773  2010.543043      48.618785
# 2       3   400  0.522613       89.222434   705.900541      52.261307
# 3       4   600  0.502326      105.300132   574.615085      50.232558
# 4       6   800  0.522613      870.486326   904.606073      52.261307
# 5       9  1000  0.483092      697.662596   746.209657      48.309179
# 6      12  1200  0.596859      657.820735   780.226325      59.685864
# 7      15  1400  0.590674      485.483937   663.691743      59.067358
# 8      20  1600  0.588832     1797.733756   862.623641      58.883249
# 9      25  1800  0.594872     1671.588914   887.564850      59.487179
# 10     32  2000  0.624339     1225.477994   702.409834      62.433862
# 11     40  2200  0.624339     2754.625570   825.708854      62.433862
# 12     51  2400  0.632124      933.302807   481.739015      63.212435
# 13     62  2600  0.605128     1559.362108   390.385227      60.512821
# 14     73  2800  0.603175     1365.567975   333.766050      60.317460
# 15     85  3000  0.619289      692.138379   295.950607      61.928934
# 16     96  3200  0.611399     1264.316353   331.261626      61.139896
# 17    108  3400  0.609626     2311.430438   374.528063      60.962567
# 18    119  3600  0.645503     5550.355519   478.502166      64.550265
# 19    130  3800  0.621469     2337.346129   338.365590      62.146893
# 20    142  4000  0.595122     3043.117417   290.187801      59.512195
# 21    153  4200  0.646154     2958.937222   305.246054      64.615385
# 22    165  4400  0.632124     5201.524855   324.661545      63.212435
# 23    176  4600  0.584615     3322.197474   335.889777      58.461538
# 24    187  4800  0.624339     2884.020383   310.767957      62.433862
# 25    199  5000  0.611399     4662.562454   355.242604      61.139896
# 26    210  5200  0.638743    20961.536858   470.321367      63.874346
# 27    221  5400  0.625641     2155.614864   239.699189      62.564103
# 28    233  5600  0.645503    20474.257883   419.274805      64.550265
# 29    244  5800  0.611399     2809.506842   227.261053      61.139896
#
#     scores.ents_p  scores.ents_r
# 0        1.826484       7.339450
# 1       61.111111      40.366972
# 2       57.777778      47.706422
# 3       50.943396      49.541284
# 4       57.777778      47.706422
# 5       51.020408      45.871560
# 6       69.512195      52.293578
# 7       67.857143      52.293578
# 8       65.909091      53.211009
# 9       67.441860      53.211009
# 10      73.750000      54.128440
# 11      73.750000      54.128440
# 12      72.619048      55.963303
# 13      68.604651      54.128440
# 14      71.250000      52.293578
# 15      69.318182      55.963303
# 16      70.238095      54.128440
# 17      73.076923      52.293578
# 18      76.250000      55.963303
# 19      80.882353      50.458716
# 20      63.541667      55.963303
# 21      73.255814      57.798165
# 22      72.619048      55.963303
# 23      66.279070      52.293578
# 24      73.750000      54.128440
# 25      70.238095      54.128440
# 26      74.390244      55.963303
# 27      70.930233      55.963303
# 28      76.250000      55.963303
# 29      70.238095      54.128440

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

df.plot(x="epoch", y=["scores.ents_f", "scores.ents_p", "scores.ents_r"], ax=axes[0])
axes[0].legend(["F1 Score", "Precision", "Recall"])

df.plot(x="step", y=["scores.ents_f", "scores.ents_p", "scores.ents_r"], ax=axes[1])
axes[1].legend(["F1 Score", "Precision", "Recall"])

plt.suptitle("Performance evolution over training steps and epochs")

plt.show()

# %%
df_ents: pd.DataFrame

with open('02/out/model-best/meta.json') as json_file:
    data = json.load(json_file)
    df_ents = pd.DataFrame(data['performance']['ents_per_type']).T
    df_ents.columns = ["Precision", "Recall", "F1"]

df_ents
# Out:
#                        Precision    Recall        F1
# TYPE_OF_APPEAL          0.846154  1.000000  0.916667
# GRANTED_AND_INDICATED   0.000000  0.000000  0.000000
# NOT_HEARD               0.666667  1.000000  0.800000
# GRANTED_TO_REVOKE       0.375000  0.272727  0.315789
# NOT_GRANTED             1.000000  0.500000  0.666667
# NOT_ENTERTAINED         0.000000  0.000000  0.000000
# RENDERED_MOOT           0.333333  0.200000  0.250000
# SUSPENDED               1.000000  0.250000  0.400000

# %%
plt_ents = df_ents.plot(kind='bar')
plt_ents.set_title("Performance per entity type")
plt_ents.set_xlabel("Entity type")
plt_ents.set_ylabel("Performance")
# Out:
# Text(0, 0.5, 'Performance')

# %% [markdown]
# # Método 3
